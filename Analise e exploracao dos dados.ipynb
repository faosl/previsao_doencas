# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
plt.rcParams['figure.figsize'] = (12,8)

# %%
resultados_df = pd.read_csv('detalhes_resultados_pre_processados.csv',sep=';',parse_dates=True)

# %%
resultados_df.describe()
# Out:
#        SEQ_REQUISICAO_ITEM  Eritrocitos  Hemoglobina  Hematocrito      VCM  \
# count             52453.00     52453.00     52453.00     52453.00 52453.00
# mean            8678367.89         4.29        12.60        37.88    88.64
# std             1058895.06         0.70         2.14         6.19     8.16
# min             6112349.00         0.73         2.50         7.90    41.00
# 25%             7812720.00         3.90        11.40        34.30    84.00
# 50%             8729491.00         4.34        12.70        38.20    89.00
# 75%             9526334.00         4.74        14.00        41.90    93.75
# max            10581717.00         8.56        22.60        66.00   141.00
#
#          CHbCM     HbCM  LEUCOCITOS  Segmentados  Eosinofilos  \
# count 52453.00 52453.00    52453.00     52453.00     52453.00
# mean     33.25    29.48    10434.10        67.74         1.83
# std       1.15     2.93     5807.31        14.48         2.21
# ...

# %%
resultados_df.drop(['Mielocitos',
                    'Metamielocitos',
                    'Linfocitos Atipicos',
                    'Bastonetes',
                    'Basofilos',
                    'Total'],axis=1,inplace=True)

# %%
ax = sns.heatmap(resultados_df.drop('SEQ_REQUISICAO_ITEM',axis=1).corr(),
                 vmin=-1,vmax=1,
                 annot=True,
                fmt=".2f")

# %%
figsize = (6,6)

# %%
resultados_df.boxplot(column='Eritrocitos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[resultados_df['Eritrocitos'] < 34.50]

# %%
resultados_df.boxplot(column='Eritrocitos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Eritrocitos',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Eritrocitos'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Hemoglobina',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[resultados_df['Hemoglobina'] < 25]

# %%
resultados_df.boxplot(column='Hemoglobina',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Hemoglobina',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Hemoglobina'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Hematocrito',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[ (resultados_df['Hematocrito'] > 3) & (resultados_df['Hematocrito'] < 70)]

# %%
resultados_df.boxplot(column='Hematocrito',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Hematocrito',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Hematocrito'}>]], dtype=object)

# %%
resultados_df.boxplot(column='VCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['VCM'] > 39) & (resultados_df['VCM'] < 150)]

# %%
resultados_df.boxplot(column='VCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='VCM',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'VCM'}>]], dtype=object)

# %%
resultados_df.boxplot(column='CHbCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['CHbCM'] > 23) & (resultados_df['CHbCM'] < 40)]

# %%
resultados_df.boxplot(column='CHbCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='CHbCM',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'CHbCM'}>]], dtype=object)

# %%
resultados_df.boxplot(column='HbCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['HbCM'] > 9) & (resultados_df['HbCM'] < 50)]

# %%
resultados_df.boxplot(column='HbCM',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='HbCM',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'HbCM'}>]], dtype=object)

# %%
resultados_df.boxplot(column='LEUCOCITOS',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['LEUCOCITOS'] < 175000)]

# %%
resultados_df.boxplot(column='LEUCOCITOS',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='LEUCOCITOS',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'LEUCOCITOS'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Segmentados',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['Segmentados'] < 101)]

# %%
resultados_df.boxplot(column='Segmentados',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Segmentados',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Segmentados'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Eosinofilos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['Eosinofilos'] < 40)]

# %%
resultados_df.boxplot(column='Eosinofilos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Eosinofilos',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Eosinofilos'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Linfocitos Tipicos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['Linfocitos Tipicos'] < 100)]

# %%
resultados_df.boxplot(column='Linfocitos Tipicos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Linfocitos Tipicos',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Linfocitos Tipicos'}>]],
#       dtype=object)

# %%
resultados_df.boxplot(column='Monocitos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['Monocitos'] < 33)]

# %%
resultados_df.boxplot(column='Monocitos',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Monocitos',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Monocitos'}>]], dtype=object)

# %%
resultados_df.boxplot(column='Plaquetas',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df = resultados_df[(resultados_df['Plaquetas'] < 500000)]

# %%
resultados_df.boxplot(column='Plaquetas',figsize=figsize)
# Out:
# <AxesSubplot:>

# %%
resultados_df.hist(column='Plaquetas',figsize=figsize)
# Out:
# array([[<AxesSubplot:title={'center':'Plaquetas'}>]], dtype=object)

# %%
resultados_df.shape
# Out:
# (52453, 13)

# %%
atendimentos_df = pd.read_csv('atendimentos.csv',sep=';',parse_dates=True)

# %%
atendimentos_df.set_index('SEQ_REQUISICAO_ITEM',inplace=True)

# %%
classe_exame_rotina = 'Z00'
nome_coluna_classes = 'GRUPO_CID'

# %%
capitulos_cids = ['A00-B99',
                  'D50-D89',
                  'E00-E90',
                  'G00-G99',
                  'J00-J99',
                  'K00-K93',
                  'M00-M99',
                  'I00-I99']

atendimentos_df = atendimentos_df[ ((atendimentos_df['COD_ABRAGENCIA'].isin(capitulos_cids)) | 
                        ((atendimentos_df[nome_coluna_classes]== classe_exame_rotina)))]

# %%
df = resultados_df.set_index('SEQ_REQUISICAO_ITEM',drop=False)\
                  .join(atendimentos_df,how='inner')

# %%
classes_gp = df[nome_coluna_classes].value_counts()
classes_gp = classes_gp[classes_gp>=200]
tops_classes = list(classes_gp.index)
classes_gp
# Out:
# J18    1848
# Z00    1538
# I64    1300
# A09     760
# J15     704
# K92     593
# I50     580
# K80     532
# J44     506
# E10     455
# A90     372
# K85     319
# I70     318
# G40     311
# K59     303
# J06     271
# I10     259
# M79     244
# I82     240
# D64     240
# J45     222
# E87     209
# J00     203
# M54     201
# Name: GRUPO_CID, dtype: int64

# %%
df_classes = pd.get_dummies(df[nome_coluna_classes])
classes_colunas = list(df_classes.columns)
df = pd.concat([df,df_classes],axis=1)

# %%
df.drop(['SEQ_REQUISICAO',
                 'FLG_SEXO',
                 'DAT_NASCIMENTO',
                 'FLG_GESTANTE',
                 'SEQ_CID',
                 'COD_ABRAGENCIA',
                 'DES_CAPITULO',                 
                 'COD_CID',
                 'NOM_CID',
                 'SEQ_REQUISICAO_ITEM'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                      Eritrocitos  Hemoglobina  Hematocrito   VCM  CHbCM  HbCM  \
# SEQ_REQUISICAO_ITEM
# 6112349                     2.26         7.20        21.40 94.70  33.80 32.50
# 6347350                     4.31        11.30        34.20 79.35  33.04 26.22
# 6397361                     4.04        11.80        34.00 84.20  34.70 29.20
# 6403389                     5.06        14.70        42.30 83.60  34.75 29.05
# 6470037                     4.96        14.50        43.10 86.90  33.64 29.23
#
#                      LEUCOCITOS  Segmentados  Eosinofilos  Linfocitos Tipicos  \
# SEQ_REQUISICAO_ITEM
# 6112349                 7980.00        82.00         0.00               13.00
# 6347350                11300.00        71.00         1.00               18.00
# 6397361                11840.00        79.00         1.00               14.00
# 6403389                 5230.00        68.80         2.70               22.80
# ...

# %%
df.shape
# Out:
# (20929, 416)

# %%
df.to_csv('input.csv',index=False,sep=';')
